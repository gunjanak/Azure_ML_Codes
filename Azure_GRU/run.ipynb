# %%
from azureml.core import Workspace, Experiment, ScriptRunConfig, Environment

# Connect to Azure ML Workspace
ws = Workspace.from_config()  # Ensure your `config.json` file is present

# Create an Azure ML experiment
experiment = Experiment(ws, "Pytorch-NN-GRU")

# Define an execution environment
env = Environment.from_conda_specification(name="pytorch-env", file_path="environment.yml")
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
from azureml.core.compute import ComputeInstance, ComputeTarget
from azureml.exceptions import ComputeTargetException



# Define compute instance name
compute_name = "compute-A"

# Set VM size (adjust as needed)
vm_size = "Standard_D2_v3"

try:
    # Check if the compute instance already exists
    compute_instance = ComputeInstance(ws, compute_name)
    print(f"Compute instance {compute_name} already exists.")

except ComputeTargetException:
    print(f"Creating new compute instance: {compute_name}")

    compute_config = ComputeInstance.provisioning_configuration(vm_size=vm_size)

    compute_instance = ComputeInstance.create(ws, compute_name, compute_config)
    compute_instance.wait_for_completion(show_output=True)

print(f"Compute instance '{compute_name}' is ready!")
# Out:
# Creating new compute instance: compute-A
#
# Creating............................................................
# Running
# Compute instance 'compute-A' is ready!

# %%
# Set up the script configuration
compute_name = "compute-A"
script_config = ScriptRunConfig(
    source_directory=".",  # Path to the script folder
    script="train.py",  
    compute_target=compute_name,  # Change to your Azure ML compute name
    environment=env,
    arguments=["--symbol","ADBL"]
)

# %%
# Submit experiment
run = experiment.submit(script_config)
print("Experiment submitted! Tracking in Azure ML Studio.")
run.wait_for_completion(show_output=True)
# Out:
# Experiment submitted! Tracking in Azure ML Studio.
# RunId: Pytorch-NN-GRU_1744121095_ac95c1e0
# Web View: https://ml.azure.com/runs/Pytorch-NN-GRU_1744121095_ac95c1e0?wsid=/subscriptions/15d6b460-1d61-4813-914e-eb2d235bceb1/resourcegroups/Azure_ML/workspaces/Azure_ml&tid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471
#
# Streaming user_logs/std_log.txt
# ===============================
#
# 2025-4-7
# /mnt/azureml/cr/j/189c5b8299fb477bad858385ed57eab6/exe/wd/helper.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   theList = df['result'][0]
# Epoch 1/100 | Loss: 0.8623 | Train MAPE: 0.19% | Test MAPE: 0.20%
# Epoch 2/100 | Loss: 0.4180 | Train MAPE: 0.12% | Test MAPE: 0.12%
# Epoch 3/100 | Loss: 0.0955 | Train MAPE: 0.04% | Test MAPE: 0.03%
# Epoch 4/100 | Loss: 0.0218 | Train MAPE: 0.02% | Test MAPE: 0.03%
# Epoch 5/100 | Loss: 0.0201 | Train MAPE: 0.02% | Test MAPE: 0.03%
# Epoch 6/100 | Loss: 0.0196 | Train MAPE: 0.02% | Test MAPE: 0.03%
# Epoch 7/100 | Loss: 0.0192 | Train MAPE: 0.02% | Test MAPE: 0.03%
# Epoch 8/100 | Loss: 0.0188 | Train MAPE: 0.02% | Test MAPE: 0.03%
# Epoch 9/100 | Loss: 0.0184 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 10/100 | Loss: 0.0180 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 11/100 | Loss: 0.0177 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 12/100 | Loss: 0.0173 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 13/100 | Loss: 0.0170 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 14/100 | Loss: 0.0167 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 15/100 | Loss: 0.0163 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 16/100 | Loss: 0.0160 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 17/100 | Loss: 0.0157 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 18/100 | Loss: 0.0155 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 19/100 | Loss: 0.0152 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 20/100 | Loss: 0.0149 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 21/100 | Loss: 0.0147 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 22/100 | Loss: 0.0144 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 23/100 | Loss: 0.0142 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 24/100 | Loss: 0.0140 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 25/100 | Loss: 0.0137 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 26/100 | Loss: 0.0135 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 27/100 | Loss: 0.0133 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 28/100 | Loss: 0.0131 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 29/100 | Loss: 0.0129 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 30/100 | Loss: 0.0127 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 31/100 | Loss: 0.0125 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 32/100 | Loss: 0.0123 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 33/100 | Loss: 0.0121 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 34/100 | Loss: 0.0119 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 35/100 | Loss: 0.0117 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 36/100 | Loss: 0.0115 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 37/100 | Loss: 0.0114 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 38/100 | Loss: 0.0112 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 39/100 | Loss: 0.0110 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 40/100 | Loss: 0.0109 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 41/100 | Loss: 0.0107 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 42/100 | Loss: 0.0106 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 43/100 | Loss: 0.0104 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 44/100 | Loss: 0.0103 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 45/100 | Loss: 0.0101 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 46/100 | Loss: 0.0100 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 47/100 | Loss: 0.0099 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 48/100 | Loss: 0.0098 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 49/100 | Loss: 0.0097 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 50/100 | Loss: 0.0096 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 51/100 | Loss: 0.0095 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 52/100 | Loss: 0.0095 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 53/100 | Loss: 0.0095 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 54/100 | Loss: 0.0095 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 55/100 | Loss: 0.0096 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 56/100 | Loss: 0.0097 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 57/100 | Loss: 0.0099 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 58/100 | Loss: 0.0099 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 59/100 | Loss: 0.0098 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 60/100 | Loss: 0.0097 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 61/100 | Loss: 0.0095 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 62/100 | Loss: 0.0094 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 63/100 | Loss: 0.0093 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 64/100 | Loss: 0.0093 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 65/100 | Loss: 0.0093 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 66/100 | Loss: 0.0093 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 67/100 | Loss: 0.0093 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 68/100 | Loss: 0.0092 | Train MAPE: 0.02% | Test MAPE: 0.02%
# Epoch 69/100 | Loss: 0.0092 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 70/100 | Loss: 0.0091 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 71/100 | Loss: 0.0091 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 72/100 | Loss: 0.0090 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 73/100 | Loss: 0.0090 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 74/100 | Loss: 0.0090 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 75/100 | Loss: 0.0089 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 76/100 | Loss: 0.0089 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 77/100 | Loss: 0.0088 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 78/100 | Loss: 0.0088 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 79/100 | Loss: 0.0088 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 80/100 | Loss: 0.0087 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 81/100 | Loss: 0.0087 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 82/100 | Loss: 0.0087 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 83/100 | Loss: 0.0086 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 84/100 | Loss: 0.0086 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 85/100 | Loss: 0.0086 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 86/100 | Loss: 0.0085 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 87/100 | Loss: 0.0085 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 88/100 | Loss: 0.0085 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 89/100 | Loss: 0.0084 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 90/100 | Loss: 0.0084 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 91/100 | Loss: 0.0084 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 92/100 | Loss: 0.0084 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 93/100 | Loss: 0.0083 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 94/100 | Loss: 0.0083 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 95/100 | Loss: 0.0083 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 96/100 | Loss: 0.0082 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 97/100 | Loss: 0.0082 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 98/100 | Loss: 0.0082 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 99/100 | Loss: 0.0082 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Epoch 100/100 | Loss: 0.0081 | Train MAPE: 0.01% | Test MAPE: 0.02%
# Train_MAPE 0.01977404681034386
# Test_MAPE 0.021576098073273896
# Model saved in outputs/pytorch_gru.pth
# Registering model pytorch_gru
# Model registered successfully
# Scaler saved at outputs/scaler.save
# Registering model scaler
# Scaler registered successfully
# Prediction plot saved at outputs/prediction_vs_actual.png
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.0546419620513916 seconds
#
# Execution Summary
# =================
# RunId: Pytorch-NN-GRU_1744121095_ac95c1e0
# Web View: https://ml.azure.com/runs/Pytorch-NN-GRU_1744121095_ac95c1e0?wsid=/subscriptions/15d6b460-1d61-4813-914e-eb2d235bceb1/resourcegroups/Azure_ML/workspaces/Azure_ml&tid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471
# {'runId': 'Pytorch-NN-GRU_1744121095_ac95c1e0',
#  'target': 'compute-A',
#  'status': 'Completed',
#  'startTimeUtc': '2025-04-08T14:05:19.693684Z',
#  'endTimeUtc': '2025-04-08T14:08:12.722757Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcdsi',
#   '_azureml.ClusterName': 'compute-A',
#   'ContentSnapshotId': '1bc9754e-b6bc-4413-8af5-599fa9c99cd9',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--symbol', 'ADBL'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'compute-A',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'pytorch-env',
#    'version': 'Autosave_2025-04-04T14:05:26Z_972f44dd',
#    'assetId': 'azureml://locations/eastus2/workspaces/7dc8b21f-b648-44b8-b5b9-8b3d06f4ce85/environments/pytorch-env/versions/Autosave_2025-04-04T14:05:26Z_972f44dd',
#    'autoRebuild': True,
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'pytorch-env',
#      'dependencies': ['python=3.10',
#       'pytorch=2.1.0',
#       'scikit-learn',
#       'pip',
#       {'pip': ['azureml-sdk', 'mlflow', 'numpy', 'matplotlib', 'pandas']}]},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20250121.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'user_logs/std_log.txt': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=sih4D7CI60dUi7PAMWlooEhK69epF%2F7HHuMbtUxOZLc%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A28Z&se=2025-04-08T22%3A08%3A28Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=07EWKDlpjdOnwthunu9IFouAmYn8%2F7trWG4Rt%2FQHUZA%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=MxHGaImYwniVIye03Sx8U0ARxR7zpDegWaTDr%2F8SjuY%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=89Ibpr7tMdvsTBSs5m7UNyO%2BU6WtTBLPSJmi2Xz8J%2FM%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=u%2B2tHZlizBy9V0b8sWc6JDhQcp%2BjUMAaNqtZ1jdiX1A%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/lifecycler/vm-bootstrapper.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/lifecycler/vm-bootstrapper.log?sv=2019-07-07&sr=b&sig=FPM4vbGikVqk5BkPJXMoYuqCx%2BD2rvGcaeS3uIpoLJo%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/metrics_capability/metrics-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/metrics_capability/metrics-capability.log?sv=2019-07-07&sr=b&sig=4FOapwWR9uhHkHqRdhSiTI4QdTo9zVgoqOSnG8mtpb0%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r',
#   'system_logs/snapshot_capability/snapshot-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1744121095_ac95c1e0/system_logs/snapshot_capability/snapshot-capability.log?sv=2019-07-07&sr=b&sig=zb%2BXISjNQ%2FFBSnhE96rwP0DiVYPO2yUx6ccl8q6g%2Bdk%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-08T13%3A57%3A57Z&ske=2025-04-10T14%3A07%3A57Z&sks=b&skv=2019-07-07&st=2025-04-08T13%3A58%3A30Z&se=2025-04-08T22%3A08%3A30Z&sp=r'},
#  'submittedBy': 'Janak Lal'}
