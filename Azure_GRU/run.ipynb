# %%
from azureml.core import Workspace, Experiment, ScriptRunConfig, Environment

# Connect to Azure ML Workspace
ws = Workspace.from_config()  # Ensure your `config.json` file is present

# Create an Azure ML experiment
experiment = Experiment(ws, "Pytorch-NN-GRU")

# Define an execution environment
env = Environment.from_conda_specification(name="pytorch-env", file_path="environment.yml")
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
from azureml.core.compute import ComputeInstance, ComputeTarget
from azureml.exceptions import ComputeTargetException



# Define compute instance name
compute_name = "compute-A42"

# Set VM size (adjust as needed)
vm_size = "Standard_DS3_v2"

try:
    # Check if the compute instance already exists
    compute_instance = ComputeInstance(ws, compute_name)
    print(f"Compute instance {compute_name} already exists.")

except ComputeTargetException:
    print(f"Creating new compute instance: {compute_name}")

    compute_config = ComputeInstance.provisioning_configuration(vm_size=vm_size)

    compute_instance = ComputeInstance.create(ws, compute_name, compute_config)
    compute_instance.wait_for_completion(show_output=True)

print(f"Compute instance '{compute_name}' is ready!")
# Out:
# Creating new compute instance: compute-A42
#
# Creating....................................................
# Running
# Compute instance 'compute-A42' is ready!

# %%
# Set up the script configuration
compute_name = "compute-A42"
script_config = ScriptRunConfig(
    source_directory=".",  # Path to the script folder
    script="train.py",  
    compute_target=compute_name,  # Change to your Azure ML compute name
    environment=env,
    arguments=["--symbol","ADBL","--input_size",1,"--hidden_size",32,"--output_size",1,"--epochs", 200]
)

# %%
# Submit experiment
run = experiment.submit(script_config)
print("Experiment submitted! Tracking in Azure ML Studio.")
run.wait_for_completion(show_output=True)
# Out:
# Experiment submitted! Tracking in Azure ML Studio.
# RunId: Pytorch-NN-GRU_1743954634_26380adf
# Web View: https://ml.azure.com/runs/Pytorch-NN-GRU_1743954634_26380adf?wsid=/subscriptions/15d6b460-1d61-4813-914e-eb2d235bceb1/resourcegroups/Azure_ML/workspaces/Azure_ml&tid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471
#
# Streaming user_logs/std_log.txt
# ===============================
#
# 2025-4-5
# /mnt/azureml/cr/j/019fae2f20eb4bf5a3759ecfebe7bb39/exe/wd/helper.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   theList = df['result'][0]
# Shape of X_train: torch.Size([936, 5, 1])
# Shape of y_train: torch.Size([936])
# Epoch no: 1
# Epoch 000: Train Loss=1.3248, Test Loss=0.4339, Test MAPE=62.45%
# Epoch no: 2
# Epoch no: 3
# Epoch no: 4
# Epoch no: 5
# Epoch no: 6
# Epoch no: 7
# Epoch no: 8
# Epoch no: 9
# Epoch no: 10
# Epoch no: 11
# Epoch 010: Train Loss=1.0893, Test Loss=0.3872, Test MAPE=42.05%
# Epoch no: 12
# Epoch no: 13
# Epoch no: 14
# Epoch no: 15
# Epoch no: 16
# Epoch no: 17
# Epoch no: 18
# Epoch no: 19
# Epoch no: 20
# Epoch no: 21
# Epoch 020: Train Loss=0.8762, Test Loss=0.3418, Test MAPE=21.42%
# Epoch no: 22
# Epoch no: 23
# Epoch no: 24
# Epoch no: 25
# Epoch no: 26
# Epoch no: 27
# Epoch no: 28
# Epoch no: 29
# Epoch no: 30
# Epoch no: 31
# Epoch 030: Train Loss=0.6624, Test Loss=0.2901, Test MAPE=4.35%
# Epoch no: 32
# Epoch no: 33
# Epoch no: 34
# Epoch no: 35
# Epoch no: 36
# Epoch no: 37
# Epoch no: 38
# Epoch no: 39
# Epoch no: 40
# Epoch no: 41
# Epoch 040: Train Loss=0.4381, Test Loss=0.2223, Test MAPE=27.43%
# Epoch no: 42
# Epoch no: 43
# Epoch no: 44
# Epoch no: 45
# Epoch no: 46
# Epoch no: 47
# Epoch no: 48
# Epoch no: 49
# Epoch no: 50
# Epoch no: 51
# Epoch 050: Train Loss=0.2169, Test Loss=0.1285, Test MAPE=49.28%
# Epoch no: 52
# Epoch no: 53
# Epoch no: 54
# Epoch no: 55
# Epoch no: 56
# Epoch no: 57
# Epoch no: 58
# Epoch no: 59
# Epoch no: 60
# Epoch no: 61
# Epoch 060: Train Loss=0.0578, Test Loss=0.0322, Test MAPE=50.65%
# Epoch no: 62
# Epoch no: 63
# Epoch no: 64
# Epoch no: 65
# Epoch no: 66
# Epoch no: 67
# Epoch no: 68
# Epoch no: 69
# Epoch no: 70
# Epoch no: 71
# Epoch 070: Train Loss=0.0231, Test Loss=0.0227, Test MAPE=22.93%
# Epoch no: 72
# Epoch no: 73
# Epoch no: 74
# Epoch no: 75
# Epoch no: 76
# Epoch no: 77
# Epoch no: 78
# Epoch no: 79
# Epoch no: 80
# Epoch no: 81
# Epoch 080: Train Loss=0.0293, Test Loss=0.0312, Test MAPE=21.46%
# Epoch no: 82
# Epoch no: 83
# Epoch no: 84
# Epoch no: 85
# Epoch no: 86
# Epoch no: 87
# Epoch no: 88
# Epoch no: 89
# Epoch no: 90
# Epoch no: 91
# Epoch 090: Train Loss=0.0211, Test Loss=0.0158, Test MAPE=23.60%
# Epoch no: 92
# Epoch no: 93
# Epoch no: 94
# Epoch no: 95
# Epoch no: 96
# Epoch no: 97
# Epoch no: 98
# Epoch no: 99
# Epoch no: 100
# Epoch 099: Train Loss=0.0210, Test Loss=0.0138, Test MAPE=25.14%
# Test_MAPE 30.962675619125367
# Model saved in outputs/pytorch_nn_gru.pth
# Registering model pytorch_nn_gru
# Model registered successfully
# Scaler saved at outputs/scaler_adbl.save
# Registering model adbl_scaler
# Scaler registered successfully
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.07998538017272949 seconds
#
# Execution Summary
# =================
# RunId: Pytorch-NN-GRU_1743954634_26380adf
# Web View: https://ml.azure.com/runs/Pytorch-NN-GRU_1743954634_26380adf?wsid=/subscriptions/15d6b460-1d61-4813-914e-eb2d235bceb1/resourcegroups/Azure_ML/workspaces/Azure_ml&tid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471
# {'runId': 'Pytorch-NN-GRU_1743954634_26380adf',
#  'target': 'compute-A42',
#  'status': 'Completed',
#  'startTimeUtc': '2025-04-06T15:50:55.029351Z',
#  'endTimeUtc': '2025-04-06T15:52:21.517069Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcdsi',
#   '_azureml.ClusterName': 'compute-A42',
#   'ContentSnapshotId': '6a25917d-4edb-4d0b-b8a6-862248206c07',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--symbol',
#    'ADBL',
#    '--input_size',
#    '1',
#    '--hidden_size',
#    '32',
#    '--output_size',
#    '1',
#    '--epochs',
#    '200'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'compute-A42',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'pytorch-env',
#    'version': 'Autosave_2025-04-04T14:05:26Z_972f44dd',
#    'assetId': 'azureml://locations/eastus2/workspaces/7dc8b21f-b648-44b8-b5b9-8b3d06f4ce85/environments/pytorch-env/versions/Autosave_2025-04-04T14:05:26Z_972f44dd',
#    'autoRebuild': True,
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'pytorch-env',
#      'dependencies': ['python=3.10',
#       'pytorch=2.1.0',
#       'scikit-learn',
#       'pip',
#       {'pip': ['azureml-sdk', 'mlflow', 'numpy', 'matplotlib', 'pandas']}]},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20250121.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'user_logs/std_log.txt': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=3TvSFMpvSR81JExG0W96AtezesEL8ULUq0vkrRWRK%2FY%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A46Z&se=2025-04-06T23%3A52%3A46Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=i%2FKDmlRVANxZ3r%2FgFQ8WnA8yeqcaStUyRnO3%2BizRA3k%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=Llqg0irtPoae1zAsdc1rvu8AQ6GLP%2BvLzXyZ%2BQtVuXo%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=Ky157vLLPmoyoHNdk8pQiYEqicwkkaZNUTDgpV4n4Nk%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=lNUbEpLgy6xpL4dKeH5qCNIIL4VkoDrpQWNaf4ZAn3c%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/lifecycler/vm-bootstrapper.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/lifecycler/vm-bootstrapper.log?sv=2019-07-07&sr=b&sig=KgIbAJGViIFif%2FFQj7PmP%2FX0eOPv3E9KeSKkR1tcwmg%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/metrics_capability/metrics-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/metrics_capability/metrics-capability.log?sv=2019-07-07&sr=b&sig=5TZO1Ai5ka%2Bmh8%2Fip41wcEfuv3rMeJ9rb1gcrp0ZdYM%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r',
#   'system_logs/snapshot_capability/snapshot-capability.log': 'https://azureml1367482566.blob.core.windows.net/azureml/ExperimentRun/dcid.Pytorch-NN-GRU_1743954634_26380adf/system_logs/snapshot_capability/snapshot-capability.log?sv=2019-07-07&sr=b&sig=mxKbtLdkMaoCSTmhsqn0FhX5nLty1eCpXutVmtXQnpo%3D&skoid=e9d74c61-f454-4e23-9ff8-d26ee82bfe51&sktid=b32f7980-cc9b-4fad-a6b9-c7f1c515d471&skt=2025-04-06T15%3A42%3A13Z&ske=2025-04-08T15%3A52%3A13Z&sks=b&skv=2019-07-07&st=2025-04-06T15%3A42%3A48Z&se=2025-04-06T23%3A52%3A48Z&sp=r'},
#  'submittedBy': 'Janak Lal'}
